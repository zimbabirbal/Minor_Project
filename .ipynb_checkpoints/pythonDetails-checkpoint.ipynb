# %%
class pdfToText:
    def __init__(self,fileName):
        self.fileName=fileName
        #holds regrexed text
        self.text=""
        #holds string of pdf data directly
        self.rawtext=""
        self.refinedText=""
        self.refinedWordWholeList=[]
        self.lineList=[]
        self.wordListEachLine=[]
        self.totalWordList=[]
        self.tagList=[]
    def convertPDFtoText(self):
        import PyPDF2
        pdfFileObj = open(self.fileName,'rb')     #'rb' for read binary mode
        pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
        noOfPages=pdfReader.numPages
        for pages in range(0,pdfReader.numPages):
            pageObj = pdfReader.getPage(pages)          #'9' is the page number
            self.rawtext+=pageObj.extractText()
        self.normalizeText()
        self.sizeOfText()
    def normalizeText(self):
        import nltk
        self.removeSpecialrefinedTextCharacterFromString()
        self.tokenizeToLine()
        self.tokenizeToWords()
        self.tokenizeToWordsEachLine()
        stopwords=nltk.corpus.stopwords.words('english')
        self.refinedWordWholeList=[word for word in self.totalWordList if word not in stopwords]
        wnl = nltk.WordNetLemmatizer()
        self.refinedWordWholeList=[wnl.lemmatize(word) for word in self.refinedWordWholeList]
        self.refinedText=' '.join(self.refinedWordWholeList)
    def removeSpecialrefinedTextCharacterFromString(self):
        import re
        self.text+= re.sub(r'[^a-zA-Z ]',r'',self.rawtext)
        
    def printAllVariables(self):
        print("\nself.text:\n"+self.text)
        print("\nself.rawtext:\n"+self.rawtext)
        print("\nself.lineList:\n")
        for line in self.lineList:
            print(line)
        print("\nself.wordListEachLine:\n")
        for line in self.wordListEachLine:
            print(line)
        print("\nself.tagList:\n")
        for line in self.tagList:
            print(line)
        print("\nself.refinedWordWholeList:\n")
        print(self.refinedWordWholeList)
        print("\nself.totalWordList:\n")
        print(self.totalWordList)
       
      
    def sizeOfText(self):
        return len(self.text)
    
    def tokenizeToLine(self):
        import nltk
        self.lineList=nltk.sent_tokenize(self.rawtext)
        
    def tokenizeToWordsEachLine(self):
        import nltk
        for line in self.lineList:
            self.wordListEachLine.append(nltk.word_tokenize(line))
            
    def tokenizeToWords(self):
        import nltk
        self.totalWordList=nltk.word_tokenize(self.text)
            
    def textVsWordGraph(self,listName=None):
        import nltk
        if listName is None:
            listName=self.totalWordList
        FDIST=nltk.FreqDist(listName)
        FDIST.plot(10,linewidth=1.0)
        print("comparing top 20 word occurance in whole text")
        
   
    def categorizePOSTag(self,listName=None):
        import nltk
        if listName is None:
            listName=self.totalWordList
        self.tagList=nltk.pos_tag(listName)

# %%
class databaseHandler:
    def __init__(self,password="ST.xavier51",databaseName="cvRanking"):
        import pymysql
        try:
            self.database=pymysql.connect("localhost","root","ST.xavier51","cvRanking")
            self.cursor = self.database.cursor()
        except Exception as e:
            print("error info %s"%e)
    def entryTheCV(self,data_CV):
        try:
            dataReturned=self.checkDuplication(data_CV[1])
            if(len(dataReturned)==0):
                add_CV="""insert into recordentry
                    (checkRecord,recordname)
                    values(%s,%s)"""
    #             add_CV="""insert into recordentry
    #                 (idrecordEntry,checkRecord,recordname)
    #                 values(%s,%s,%s)"""
                #data_CV=("yes","ram")
                print(data_CV)
                self.cursor.execute(add_CV,data_CV)
                self.database.commit()
                print("CV is entered")
                return True;
            else:
                print("CV already present\n location at %s"%str(dataReturned))
                return False
        except Exception as e:
            print("in entryTheCV\t"+str(e))
            return False
    def checkDuplication(self,name_CV):
        try:
            check_CV="""select* from recordentry as re where re.recordname=%s"""
            self.cursor.execute(check_CV,name_CV)
            result = self.cursor.fetchall()
        except Exception as e:
            print("in process checkDuplication\t"+str(e))
        return result
            

        
    def closeConnection(self):
        self.database.close()

# %%
class CV_manager:
    def __init__(self):
        self.database=databaseHandler()
        from sklearn.feature_extraction.text import CountVectorizer
        self.vectorizer=CountVectorizer()
        self.CVList=[]
        #refined word coll
        self.textCollectionForDM=[]
        self.wordCollection=[]
        self.tagCollection=[]
        self.documentMatrix=[]
        self.featureVectorDict={}
        self.normalizedVectorValue=[]
        self.fileNamesWithPath=[]

    def list_CVs(self,rootPath):
        import os
        for root, dirs, files in os.walk(rootPath):
            for name in files:
                self.fileNamesWithPath.append(os.path.join(root, name))
    def addCVFromSavedList(self):
        for file in self.fileNamesWithPath:
            if(self.database.entryTheCV(("yes",file))):
                pdf=pdfToText(file)
                self.CVList.append(pdf)
    def doConversion(self):
        for cv in self.CVList:
            cv.convertPDFtoText();
    def size(self):
        return len(self.CVList)
    def compareTotalLines(self):
        import matplotlib.pyplot as plt
        for cvNum,cv in enumerate(self.CVList):
            if not cv.text:
                #conversion not done
                cv.convertPDFtoText()
            #conversion handles all the tokenization tasks
            plt.plot(cvNum+1,len(cv.lineList),'g^',linewidth=2.0)
            plt.xlabel('CV')
            plt.ylabel('totalLines')
        plt.show()
    def compareTotalWords(self):
        import matplotlib.pyplot as plt
        for cvNum,cv in enumerate(self.CVList):
            if not cv.text:
                #conversion not done
                cv.convertPDFtoText()
            #conversion handles all the tokenization tasks
            plt.plot(cvNum+1,len(cv.refinedWordWholeList),'g^',linewidth=2.0)
            plt.xlabel('CV')
            plt.ylabel('totalLines')
        plt.show()
    def PopualarWords(self,number=20):
        import nltk
        for cvNum,cv in enumerate(self.CVList):
            if not cv.text:
                #conversion not done
                cv.convertPDFtoText()
            FDIST=nltk.FreqDist(cv.refinedWordWholeList)
            FDIST.plot(number,linewidth=1.0)
            print("comparing top %d word occurance in whole text of %d"%(number,cvNum+1))
    def collectAllWordsFromCVList(self):
        for cv in self.CVList:
            for word in cv.refinedWordWholeList:
                self.wordCollection.append(word)
    def frequentWordsGraph(self,wordList=None,number=20):
        import nltk
        if wordList is None:
            wordList=self.wordCollection
        FDIST=nltk.FreqDist(wordList)
        FDIST.plot(number,linewidth=1.0)
        print("comparing top %d word occurance in whole CV collection"%(number))
    def tagAllWordsFromCVList(self):
        import nltk
        if self.wordCollection is None:
            self.collectAllWordsFromCVList()
        self.tagCollection=(nltk.pos_tag(self.wordCollection))
    def getRequierdPOSGraph(self,selectionList):
        import nltk
        NNPList=[]
        if self.tagCollection is None:
            self.tagAllWordsFromCVList()
        for word in self.tagCollection:
            if word[-1] in selectionList:
                NNPList.append(word)
        self.frequentWordsGraph(NNPList)
    def convertToDocumentMatrix(self,frequency):
        for cv in self.CVList:
            self.textCollectionForDM.append(cv.refinedText)
        self.documentMatrix=self.vectorizer.fit_transform(self.textCollectionForDM)
        #print(self.vectorizer.vocabulary_)
        self.getFrequencyTableOfWords(frequency)
        self.normalizeFeatureVectors()
            #to comment or uncomment ctrl+/
    def getFrequencyTableOfWords(self,frequency):
        import numpy as np
        import json
        import matplotlib.pyplot as plt
        vocab=self.vectorizer.get_feature_names()
        dist = np.sum(self.documentMatrix.toarray(), axis=0)
        for tag, countTF in zip(vocab, dist):
            if(countTF > frequency):
                self.featureVectorDict.update({tag:int(countTF)})
        print(self.featureVectorDict)
        with open("C:\\Users\\sagar\\Desktop\\CV coll\\documentMatrixWord.txt","w") as file:
            json.dump(self.featureVectorDict, file)
        file.close()
    def normalizeFeatureVectors(self):
        from sklearn.preprocessing import normalize
        import numpy as np
        vectorValue=[]
        for key in self.featureVectorDict:
            vectorValue.append(self.featureVectorDict[key])
        datas = np.asarray(vectorValue, dtype=np.float)
        datas =normalize(datas, norm='l2')
        #converting numpy.array to list
        for r in datas:
            for column in r:
                self.normalizedVectorValue.append(column)
        print(self.normalizedVectorValue)

# %%
cmp=CV_manager()
cmp.list_CVs("C:\\Users\\sagar\\Desktop\\CV coll\\kailesh")
cmp.addCVFromSavedList()
cmp.doConversion()
# Out:
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Agnes-Szelag.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Alison-Haller.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Brad-Blackburn.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Bruce-Jones.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Carolyn-Carmel.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Christina-Le-Sesne.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Christopher-Mackey.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Cosmo-Nardozza.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Craig-Thacker.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Cristopher-Schafer.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Daniel-Montgomery.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\David-Cordon.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\David-Hindelang.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\David-Hunter.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\David-Moshier.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Denise-Sucik.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Destiny-Washington.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Devan-Brush.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Eric-Bronk.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Hannah-Nichols.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Jack-Siler.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Jayne-McELHENY.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Jessica-Yen.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\John-C-Clisham.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Jonathan-Eaton.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Joseph-Adrien-Munoz.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Josh-Becker.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\July-Lopez.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Karena-Taveras-Lugo.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Kevin-Kolbe.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Kristin-Dunn.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Lauren-Milewski.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Luis-Mata-R.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Marc-Steffensen.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Marcus-Bickler.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Melanie-Mikel.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Michael-Kunhenn.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Michael-Lay.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Michael-Showalter.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Michelle-Collins.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Nashona-Haldane.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Patricia-McNair.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Philip-Dirlam.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Ryan-Flynn.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Sara-Chamberlain.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Stephanie-Kemp.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Stephanie-Valderrama.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Tammy-Morse.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Timothy-Rabb.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\creative director\\Tracy-Jones.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Aaron-Shaw.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Abdul-Malik-Mahmud.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Andre-Doumad.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Anthony-Mendez.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Charles-Carper.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Charles-Webb.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Chris-McGlade.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Christian-Hernandez.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Ciara-Holmes.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Daniel-Lam-Tat-Yan.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Edward-Reyes.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Erick-Dressler.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Fouad-Amiri.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\George-Quinn.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Glenn-Gallimore.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Hongjun-Tao.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Jacob-Abreu.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Jaksanapong-Tilapornputt.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\Jarvis-Charles.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\game developer\\
pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\project manager\\Warren-Ford.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Ambika-Bopshetty.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Bianca-Martinez.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Bianca-Serrano.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Bradley-Sanchez.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Brandon-Killian.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Brian-Thompson.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Chaitanya-Mavaluru.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Chaitra-Neelakanta.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Charlie-Boykin.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Cheryl-Ross.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Denise-Dunning.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Devendra-Pahari.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Dwight-Neil.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Gordon-Che.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Greeshma-Raj.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Hector-Gamez.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Jean-Patrick-Amadje.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Jessica-Crenshaw.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\John-Garza.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Jonathan-O39Rourke.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Jorge-Alfonso.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Julio-Garcia.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Kevin-Leis.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Kevin-Mason.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Kevin-Mason_2.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Kevin-Thompson.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\LaShonda-Wright.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Leopold-Kokou.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Lucy-Chardon.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Matt-Stubblefield.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Panth-Shah.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Patrick-Cranfill.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Patrick-Ladu.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Piercy-Sparks.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Prashil-Shah.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Rafal-Szymanski.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Reynaldo-Reyes.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Reynier-Arias.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Richard-Crossley.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Ricky-Pacheco.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\rosa-aguilar-de-barba.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Samuel-Gilbert.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Sean-Blice.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Sharifa-Shaik.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Siddharth-Kapil.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Tavern-Hampton.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Touhmong-Lor.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Travis-Gano.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Veronica-Gonzales.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Victorino-Ouano.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Walter-Stark.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\Wannipa-Johnson.pdf')
# CV is entered
# ('yes', 'C:\\Users\\sagar\\Desktop\\CV coll\\kailesh\\quality inspector\\William-Gregersen.pdf')
# CV is entered

# %%
 cmp.convertToDocumentMatrix(30)
# Out:
# {'ability': 93, 'able': 39, 'access': 80, 'account': 85, 'acquisition': 46, 'across': 73, 'action': 78, 'active': 34, 'activity': 110, 'ad': 36, 'additional': 51, 'administration': 111, 'administrative': 45, 'adobe': 101, 'advanced': 34, 'advertising': 77, 'agency': 69, 'agile': 63, 'also': 71, 'analysis': 178, 'analyst': 63, 'android': 51, 'annual': 59, 'anywhereauthorized': 43, 'applicant': 71, 'application': 254, 'appropriate': 48, 'approval': 37, 'april': 46, 'area': 72, 'art': 127, 'artist': 39, 'arts': 47, 'as': 34, 'aspect': 43, 'assessment': 43, 'assigned': 47, 'assist': 67, 'assistant': 32, 'assisted': 58, 'assurance': 57, 'audit': 47, 'august': 87, 'average': 33, 'award': 38, 'background': 33, 'based': 115, 'basic': 73, 'benefit': 103, 'best': 55, 'board': 56, 'brand': 82, 'branding': 70, 'budget': 149, 'build': 46, 'building': 53, 'business': 490, 'ca': 46, 'call': 62, 'campaign': 50, 'candidate': 203, 'card': 35, 'care': 55, 'career': 45, 'case': 62, 'center': 95, 'certification': 34, 'certified': 44, 'change': 113, 'charge': 36, 'check': 62, 'chicago': 32, 'cisco': 32, 'city': 34, 'claim': 42, 'class': 33, 'client': 367, 'closely': 44, 'coaching': 34, 'code': 42, 'college': 118, 'commercial': 36, 'communicate': 34, 'communication': 156, 'community': 60, 'company': 324, 'compensation': 72, 'complete': 39, 'completed': 49, 'completion': 32, 'complex': 45, 'compliance': 112, 'component': 41, 'computer': 242, 'concept': 69, 'conduct': 41, 'conducted': 75, 'configuration': 40, 'construction': 59, 'consult
# %%
cmp.compareTotalLines()

# %%
cmp.compareTotalWords()

# %%
# textCollectionForDM=['i am sagar sagar','i is hero sagar']
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.feature_extraction.text import TfidfTransformer
# vectorizer=CountVectorizer()
# documentMatrix=vectorizer.fit_transform(textCollectionForDM)
# tfidf = TfidfTransformer(norm="l2")
# tfidf.fit(documentMatrix)
# documentMatrixNormalized=tfidf.transform(documentMatrix)

# %%
# import numpy as np
# # print(documentMatrix.toarray())
# # print(documentMatrixNormalized.toarray())
# # x=[1,2,3,4]
# # y=[5,6,7,8]
# # vocab=vectorizer.get_feature_names()
# # dist = documentMatrix.toarray()
# print(type(documentMatrix))
# # for vectors in dist:
# #     print(vectors)
# from sklearn.preprocessing import normalize
# data = np.array(documentMatrix.toarray())
# print(data)
# data =normalize(data, norm='l2')
# print(data)

# # for item,freqn in zip(vocab, dist):
# #         if(freqn>2):
# #             print(item,freqn)
# #print(count)

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# vocab=vectorizer.get_feature_names()
# dist = np.sum(documentMatrix.toarray(), axis=0)
# print(dist)
# yLocation=np.arange(len(dist))
# width = 0.35
# fig, ax = plt.subplots()
# for tag, count in zip(vocab, dist):
#     print(count, tag) 
# plt.bar(yLocation, dist, align='center', alpha=0.5)
# plt.xticks(yLocation, vocab)
# plt.ylabel('words')
# plt.title('comp')
 
# print(plt.show())

# %%
# print(vectorizer.vocabulary_)
# for x in documentMatrix:
#     print(x[0][0])

# %%
# import numpy as np
# from sklearn.preprocessing import normalize
# vectorValue=[1,2,3,4,5]
# data = np.asarray(vectorValue,dtype=np.float)
# data
# data1 =normalize(data, norm='l2')
# x=[]
# for r in data1:
#     print(data1[0])
#     for column in r:
#         print(column)
#         x.append(column)
#         #print(data1[0][column])
# x

# %%
#len(cmp.normalizedVectorValue)

# %%
# import numpy as np
# from sklearn.cluster import MeanShift
# from sklearn.datasets.samples_generator import make_blobs
# import matplotlib.pyplot as plt
# from matplotlib import style
# style.use("ggplot")
# #plt.scatter(cmp.normalizedVectorValue)
# #plt.show()
# ms = MeanShift()
# ms.fit(cmp.normalizedVectorValue)
# labels = ms.labels_
# cluster_centers = ms.cluster_centers_
# print(cluster_centers)

# %%
# filepath=("C:\\Users\\sagar\\Desktop\\CV coll")
# import os
# try:
#     if(os.path.exists(filepath)):
#         for filename in os.listdir(filepath):
#             print(filename)
#             print(os.path.isfile(filename))
#     else:
#         print("path not found")
#             #print("directory")
# #         if filename.endswith(".pdf"):
# #                 print(filename)
# #         else:
# #             print("files not found in required format")
# except:
#     print("location not valid")
# #pdfFileObj = open(filepath+'.pdf','rb')

# %%
# import os

# def list_files(dir):
#     r = []
#     for root, dirs, files in os.walk(dir):
#         for name in files:
#             r.append(os.path.join(root, name))
#     return r
# list_files(filepath)
